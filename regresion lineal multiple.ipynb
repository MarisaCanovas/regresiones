# %%
#Se importan la librerias a utilizar 
from sklearn import datasets, linear_model 
()
#Importamos los datos de la misma librería de scikit-learn 
boston = datasets. load_boston() 
print (boston) 
print() 
()
#Verifico la información contenida en el dataset 
print('Información en el dataset:') 
print (boston.keys()) 
print() 
()
#Verifico las características del dataset 
print('Características del dataset:') 
print(boston.DESCR) 
()
#Verifico la información de las columnas 
print('Nombres columnas :') 
print(boston.feature_names) 
()
 ## ###### PREPARAR LA DATA REGRESIÓN LINEAL MULTIPLE ###   1111111111
#Seleccionamos las columna 5, 6 y 7 del dataset 
X_multiple=boston.data[:, 5:8] 
print (X_multiple) 
()
print('caracteristicas del set:')####22222
print(boston.DESCR)
()
print('cantidad de datos')#######3
print(boston.data.shape)
()
#verifica la info de las columnas########4
print('nombre de columnas')
print(boston.feature_names)
()
#preparar la data regresion########5
X_multiple=boston.data[:,5:8]
print(X_multiple)
()
#defino los datos correspondientes a la etiquetas######6
y_multiple = boston.target 
()
from sklearn.model_selection import train_test_split #######7
# Separo los datos de "train" en entrenamiento y prueba para probar los algoritmos 
X_train, X_test, y_train, y_test=train_test_split(X_multiple, y_multiple, test_size=0.2) 
()
#Defino el algoritmo a utilizar #######8
lr_multiple=linear_model.LinearRegression()
()
y_multiple=boston.target#####9
#DEFINO LOS DATOS CORRESPONDIENTES A LAS ETIQUETAS
()
#IMPLEMENTACION DE REGRESION LINEAL MULTIPLE######10
from sklearn.model_selection import train_test_split
()
#Separo los datos de "train" en entrenamiento y prueba para probar los algoritmos #######11
X_train, X_test, y_train, y_test =train_test_split (X_multiple, y_multiple, test_size=0.2)
()
#Defino el algoritmo a utilizar #######12
lr_multiple=linear_model.LinearRegression()
()
#entreno el model#####13
lr_multiple.fit(X_train,y_train)
()
 #Separo los datos de "train" en entrenamiento y prueba para probar los algoritmos ######14
X_train, X_test, y_train, y_test = train_test_split(X_multiple, y_multiple, test_size=0.2) 
()
#preparar la data regresion########15 SELECCIONO  COLUMNAS  5 6  7  8
X_multiple=boston.data[:,5:8]
print(X_multiple)
()
#Entreno el modelo #####16
lr_multiple. fit (X_train, y_train) 
()
 #Realizo una predicción ####17
Y_pred_multiple = lr_multiple.predict(X_test)
()
print('DATOS DEL MODELO REGRESIÓN LINEAL MULTIPLE') ####18
print() 
print('Valor de las pendientes o coeficientes "a":') 
print(lr_multiple.coef_)
()
print('Valor de la intersección o coeficiente "b":') ####19
print(lr_multiple.intercept_)
()
print('Precisión del modelo:') #20
print(lr_multiple.score (X_train, y_train))
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]]), 'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
# ...

# %%
#Se importan la librerias a utilizar 
from sklearn import datasets, linear_model

# %%
#Importamos los datos de la misma librería de scikit-learn 
boston = datasets. load_boston() 
print (boston) 
print()
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]]), 'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
# ...

# %%
#Verifico la información contenida en el dataset 
print('Información en el dataset:') 
print (boston.keys()) 
print()
# Out:
# Información en el dataset:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename', 'data_module'])

# %%
#Verifico las características del dataset 
print('Características del dataset:') 
print(boston.DESCR)
# Out:
# Características del dataset:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
#Verifico las características del dataset 
print('Características del dataset:') 
print(boston.DESCR)
# Out:
# Cantidad de datos:
# (506, 13)

# %%
#Verifico la información de las columnas 
print('Nombres columnas :') 
print(boston.feature_names)
# Out:
# Nombres columnas :
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
 ## ###### PREPARAR LA DATA REGRESIÓN LINEAL MULTIPLE ###   1111111111
#Seleccionamos las columna 5, 6 y 7 del dataset 
X_multiple=boston.data[:, 5:8] 
print (X_multiple)
# Out:
# [[ 6.575  65.2     4.09  ]
#  [ 6.421  78.9     4.9671]
#  [ 7.185  61.1     4.9671]
#  ...
#  [ 6.976  91.      2.1675]
#  [ 6.794  89.3     2.3889]
#  [ 6.03   80.8     2.505 ]]

# %%
print('caracteristicas del set:')####22222
print(boston.DESCR)
# Out:
# caracteristicas del set:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
print('cantidad de datos')#######3
print(boston.data.shape)
# Out:
# cantidad de datos
# (506, 13)

# %%
#verifica la info de las columnas########4
print('nombre de columnas')
print(boston.feature_names)
# Out:
# nombre de columnas
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
#preparar la data regresion########5
X_multiple=boston.data[:,5:8]
print(X_multiple)
# Out:
# [[ 6.575  65.2     4.09  ]
#  [ 6.421  78.9     4.9671]
#  [ 7.185  61.1     4.9671]
#  ...
#  [ 6.976  91.      2.1675]
#  [ 6.794  89.3     2.3889]
#  [ 6.03   80.8     2.505 ]]

# %%
#defino los datos correspondientes a la etiquetas######6
y_multiple = boston.target

# %%
from sklearn.model_selection import train_test_split #######7
# Separo los datos de "train" en entrenamiento y prueba para probar los algoritmos 
X_train, X_test, y_train, y_test=train_test_split(X_multiple, y_multiple, test_size=0.2)

# %%
#Defino el algoritmo a utilizar #######8
lr_multiple=linear_model.LinearRegression()

# %%
y_multiple=boston.target#####9
#DEFINO LOS DATOS CORRESPONDIENTES A LAS ETIQUETAS

# %%
#IMPLEMENTACION DE REGRESION LINEAL MULTIPLE######10
from sklearn.model_selection import train_test_split

# %%
#Separo los datos de "train" en entrenamiento y prueba para probar los algoritmos #######11
X_train, X_test, y_train, y_test =train_test_split (X_multiple, y_multiple, test_size=0.2)

# %%
#Defino el algoritmo a utilizar #######12
lr_multiple=linear_model.LinearRegression()

# %%
#entreno el model#####13
lr_multiple.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
 #Separo los datos de "train" en entrenamiento y prueba para probar los algoritmos ######14
X_train, X_test, y_train, y_test = train_test_split(X_multiple, y_multiple, test_size=0.2)

# %%
#Defino el algoritmo a utilizar ####15
lr_multiple=linear_model. LinearRegression()

# %%
#Entreno el modelo #####16
lr_multiple. fit (X_train, y_train)
# Out:
# LinearRegression()

# %%
 #Realizo una predicción ####17
Y_pred_multiple = lr_multiple.predict(X_test)

# %%
print('DATOS DEL MODELO REGRESIÓN LINEAL MULTIPLE') ####18
print() 
print('Valor de las pendientes o coeficientes "a":') 
print(lr_multiple.coef_)
# Out:
# DATOS DEL MODELO REGRESIÓN LINEAL MULTIPLE
#
# Valor de las pendientes o coeficientes "a":
# [ 8.00897219 -0.09385452 -0.41242557]

# %%
print('Valor de la intersección o coeficiente "b":') ####19
print(lr_multiple.intercept_)
# Out:
# Valor de la intersección o coeficiente "b":
# -19.8582221164905

# %%
print('Precisión del modelo:') #20
print(lr_multiple.score (X_train, y_train))
# Out:
# Precisión del modelo:
# 0.5097855804378186

# %% [markdown]
# EJERCICIO 1 columnas   CRIM, ZN,INDUS,CHAS

# %%
 ## ###### PREPARAR LA DATA REGRESIÓN LINEAL MULTIPLE ###   1111111111
#Seleccionamos las columna 1, 2,3 y 4 del dataset 
X_multiple=boston.data[:, 1:5] 
print (X_multiple)
# Out:
# [[18.     2.31   0.     0.538]
#  [ 0.     7.07   0.     0.469]
#  [ 0.     7.07   0.     0.469]
#  ...
#  [ 0.    11.93   0.     0.573]
#  [ 0.    11.93   0.     0.573]
#  [ 0.    11.93   0.     0.573]]

# %%
print('caracteristicas del set:')####22222
print(boston.DESCR)
# Out:
# caracteristicas del set:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
print('cantidad de datos')#######3
print(boston.data.shape)
# Out:
# cantidad de datos
# (506, 13)

# %%
#verifica la info de las columnas########4
print('nombre de columnas')
print(boston.feature_names)
# Out:
# nombre de columnas
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
#preparar la data regresion########5 SELECCIONO  COLUMNAS  5 6  7  8
X_multiple=boston.data[:,5:8]
print(X_multiple)
# Out:
# [[ 6.575  65.2     4.09  ]
#  [ 6.421  78.9     4.9671]
#  [ 7.185  61.1     4.9671]
#  ...
#  [ 6.976  91.      2.1675]
#  [ 6.794  89.3     2.3889]
#  [ 6.03   80.8     2.505 ]]

# %%
#defino los datos correspondientes a la etiquetas######6
y_multiple = boston.target

# %%
from sklearn.model_selection import train_test_split #######7
# Separo los datos de "train" en entrenamiento y prueba para probar los algoritmos 
X_train, X_test, y_train, y_test=train_test_split(X_multiple, y_multiple, test_size=0.2)

# %%
#Defino el algoritmo a utilizar #######8
lr_multiple=linear_model.LinearRegression()

# %%
y_multiple=boston.target#####9
#DEFINO LOS DATOS CORRESPONDIENTES A LAS ETIQUETAS

# %%
#IMPLEMENTACION DE REGRESION LINEAL MULTIPLE######10
from sklearn.model_selection import train_test_split

# %%
#Separo los datos de "train" en entrenamiento y prueba para probar los algoritmos #######11
X_train, X_test, y_train, y_test =train_test_split (X_multiple, y_multiple, test_size=0.2)

# %%
#Defino el algoritmo a utilizar #######12
lr_multiple=linear_model.LinearRegression()

# %%
#entreno el model#####13
lr_multiple.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
 #Separo los datos de "train" en entrenamiento y prueba para probar los algoritmos ######14
X_train, X_test, y_train, y_test = train_test_split(X_multiple, y_multiple, test_size=0.2)

# %%
#Defino el algoritmo a utilizar ####15
lr_multiple=linear_model. LinearRegression()

# %%
#Entreno el modelo #####16
lr_multiple. fit (X_train, y_train)
# Out:
# LinearRegression()

# %%
 #Realizo una predicción ####17
Y_pred_multiple = lr_multiple.predict(X_test)

# %%
print('DATOS DEL MODELO REGRESIÓN LINEAL MULTIPLE') ####18
print() 
print('Valor de las pendientes o coeficientes "a":') 
print(lr_multiple.coef_)
# Out:
# DATOS DEL MODELO REGRESIÓN LINEAL MULTIPLE
#
# Valor de las pendientes o coeficientes "a":
# [ 8.48093165 -0.10328196 -0.4071956 ]

# %%
print('Valor de la intersección o coeficiente "b":') ####19
print(lr_multiple.intercept_)
# Out:
# Valor de la intersección o coeficiente "b":
# -22.5076171600008

# %%
print('Precisión del modelo:') #20
print(lr_multiple.score (X_train, y_train))
# Out:
# Precisión del modelo:
# 0.5458171714604607

# %% [markdown]
# EJERCICIO 2 CRIM,NOX,RAD,TSTAT

# %%
 ## ###### PREPARAR LA DATA REGRESIÓN LINEAL MULTIPLE ###   1111111111
#Seleccionamos las columna  0 4   8   12  del dataset 
X_multiple=boston.data[:, 0:12:4] 
print (X_multiple)
# Out:
# [[0.00632 0.538   1.     ]
#  [0.02731 0.469   2.     ]
#  [0.02729 0.469   2.     ]
#  ...
#  [0.06076 0.573   1.     ]
#  [0.10959 0.573   1.     ]
#  [0.04741 0.573   1.     ]]

# %%
print('caracteristicas del set:')####22222
print(boston.DESCR)
# Out:
# caracteristicas del set:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
print('cantidad de datos')#######3
print(boston.data.shape)
# Out:
# cantidad de datos
# (506, 13)

# %%
#verifica la info de las columnas########4
print('nombre de columnas')
print(boston.feature_names)
# Out:
# nombre de columnas
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
#preparar la data regresion########5 SELECCIONO  COLUMNAS  0 4 8 12 
X_multiple=boston.data[:,0:12:4]
print(X_multiple)
# Out:
# [[0.00632 0.538   1.     ]
#  [0.02731 0.469   2.     ]
#  [0.02729 0.469   2.     ]
#  ...
#  [0.06076 0.573   1.     ]
#  [0.10959 0.573   1.     ]
#  [0.04741 0.573   1.     ]]

# %%
#defino los datos correspondientes a la etiquetas######6
y_multiple = boston.target

# %%
from sklearn.model_selection import train_test_split #######7
# Separo los datos de "train" en entrenamiento y prueba para probar los algoritmos 
X_train, X_test, y_train, y_test=train_test_split(X_multiple, y_multiple, test_size=0.2)

# %%
#Defino el algoritmo a utilizar #######8
lr_multiple=linear_model.LinearRegression()

# %%
y_multiple=boston.target#####9
#DEFINO LOS DATOS CORRESPONDIENTES A LAS ETIQUETAS

# %%
#IMPLEMENTACION DE REGRESION LINEAL MULTIPLE######10
from sklearn.model_selection import train_test_split

# %%
#Separo los datos de "train" en entrenamiento y prueba para probar los algoritmos #######11
X_train, X_test, y_train, y_test =train_test_split (X_multiple, y_multiple, test_size=0.2)

# %%
#Defino el algoritmo a utilizar #######12
lr_multiple=linear_model.LinearRegression()

# %%
#entreno el model#####13
lr_multiple.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
 #Separo los datos de "train" en entrenamiento y prueba para probar los algoritmos ######14
X_train, X_test, y_train, y_test = train_test_split(X_multiple, y_multiple, test_size=0.2)

# %%
#Defino el algoritmo a utilizar ####15
lr_multiple=linear_model. LinearRegression()

# %%
#Entreno el modelo #####16
lr_multiple. fit (X_train, y_train)
# Out:
# LinearRegression()

# %%
 #Realizo una predicción ####17
Y_pred_multiple = lr_multiple.predict(X_test)

# %%
print('DATOS DEL MODELO REGRESIÓN LINEAL MULTIPLE') ####18
print() 
print('Valor de las pendientes o coeficientes "a":') 
print(lr_multiple.coef_)
# Out:
# DATOS DEL MODELO REGRESIÓN LINEAL MULTIPLE
#
# Valor de las pendientes o coeficientes "a":
# [ -0.23980802 -22.90036927  -0.05537979]

# %%
print('Valor de la intersección o coeficiente "b":') ####19
print(lr_multiple.intercept_)
# Out:
# Valor de la intersección o coeficiente "b":
# 36.58792594113717

# %%
print('Precisión del modelo:') #20
print(lr_multiple.score (X_train, y_train))
# Out:
# Precisión del modelo:
# 0.22823110232335508

# %% [markdown]
# EJERCICIO 3 CRIM,RM,B,LSTAT

# %%
 ## ###### PREPARAR LA DATA REGRESIÓN LINEAL MULTIPLE ###   1111111111
#Seleccionamos las columna 0, 11 ,5 y 12 del dataset 

# Assuming boston dataset is already imported
seleccion = [0, 5, 11, 12]
X_multiple = boston.data[:, seleccion]

print(X_multiple)
# Out:
# [[6.3200e-03 6.5750e+00 3.9690e+02 4.9800e+00]
#  [2.7310e-02 6.4210e+00 3.9690e+02 9.1400e+00]
#  [2.7290e-02 7.1850e+00 3.9283e+02 4.0300e+00]
#  ...
#  [6.0760e-02 6.9760e+00 3.9690e+02 5.6400e+00]
#  [1.0959e-01 6.7940e+00 3.9345e+02 6.4800e+00]
#  [4.7410e-02 6.0300e+00 3.9690e+02 7.8800e+00]]

# %%
print('caracteristicas del set:')####22222
print(boston.DESCR)
# Out:
# caracteristicas del set:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
print('cantidad de datos')#######3
print(boston.data.shape)
# Out:
# cantidad de datos
# (506, 13)

# %%
#verifica la info de las columnas########4
print('nombre de columnas')
print(boston.feature_names)
# Out:
# nombre de columnas
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
#preparar la data regresion########15 SELECCIONO  COLUMNAS  5 6  7  8
X_multiple=boston.data[:,5:8]
print(X_multiple)
# Out:
# [[ 6.575  65.2     4.09  ]
#  [ 6.421  78.9     4.9671]
#  [ 7.185  61.1     4.9671]
#  ...
#  [ 6.976  91.      2.1675]
#  [ 6.794  89.3     2.3889]
#  [ 6.03   80.8     2.505 ]]

# %%
#defino los datos correspondientes a la etiquetas######6
y_multiple = boston.target

# %%
from sklearn.model_selection import train_test_split #######7
# Separo los datos de "train" en entrenamiento y prueba para probar los algoritmos 
X_train, X_test, y_train, y_test=train_test_split(X_multiple, y_multiple, test_size=0.2)

# %%
#Defino el algoritmo a utilizar #######8
lr_multiple=linear_model.LinearRegression()

# %%
y_multiple=boston.target#####9
#DEFINO LOS DATOS CORRESPONDIENTES A LAS ETIQUETAS

# %%
#IMPLEMENTACION DE REGRESION LINEAL MULTIPLE######10
from sklearn.model_selection import train_test_split

# %%
#Separo los datos de "train" en entrenamiento y prueba para probar los algoritmos #######11
X_train, X_test, y_train, y_test =train_test_split (X_multiple, y_multiple, test_size=0.2)

# %%
#Defino el algoritmo a utilizar #######12
lr_multiple=linear_model.LinearRegression()

# %%
#entreno el model#####13
lr_multiple.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
 #Separo los datos de "train" en entrenamiento y prueba para probar los algoritmos ######14
X_train, X_test, y_train, y_test = train_test_split(X_multiple, y_multiple, test_size=0.2)

# %%
#Defino el algoritmo a utilizar ####15
lr_multiple=linear_model. LinearRegression()

# %%
#Entreno el modelo #####16
lr_multiple. fit (X_train, y_train)
# Out:
# LinearRegression()

# %%
 #Realizo una predicción ####17
Y_pred_multiple = lr_multiple.predict(X_test)

# %%
print('DATOS DEL MODELO REGRESIÓN LINEAL MULTIPLE') ####18
print() 
print('Valor de las pendientes o coeficientes "a":') 
print(lr_multiple.coef_)
# Out:
# DATOS DEL MODELO REGRESIÓN LINEAL MULTIPLE
#
# Valor de las pendientes o coeficientes "a":
# [ 9.46306465 -0.09587386 -0.39190738]

# %%
print('Valor de la intersección o coeficiente "b":') ####19
print(lr_multiple.intercept_)
# Out:
# Valor de la intersección o coeficiente "b":
# -29.064956716330823

# %%
print('Precisión del modelo:') #20
print(lr_multiple.score (X_train, y_train))
# Out:
# Precisión del modelo:
# 0.6114882668120214

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=40a80d7b-3162-4777-afe5-44a88b90cd41' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
